# %%
import os
import random
import string
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import shutil
# Define the size of the image
IMAGE_WIDTH = 72
IMAGE_HEIGHT = 72

# Define the path to the Thai font file
THAI_FONT_FILE = "Sarun's_ThangLuang.ttf"
# Define the characters to be included in the dataset
CHARACTERS = ''.join([
    '0123456789',  # Numbers
    'กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรฤลฦวศษสหฬอฮ'  # Thai characters
])

# Define the number of images to be generated for each character
NUM_IMAGES_PER_CHARACTER = 8

# Define the output directory for the dataset
OUTPUT_DIR = 'dataset/'

if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR)
# Create the output directory if it doesn't exist
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# Load the Thai font
font = ImageFont.truetype(THAI_FONT_FILE, IMAGE_WIDTH)

# Generate the images
for char in CHARACTERS:
    if not os.path.exists(OUTPUT_DIR+char):
        os.makedirs(OUTPUT_DIR+char)
    for i in range(NUM_IMAGES_PER_CHARACTER):
        # Create a new image
        image = Image.new('L', (IMAGE_WIDTH, IMAGE_HEIGHT), color=255)
        
        # Draw the character on the image
        draw = ImageDraw.Draw(image)
        draw.text((20, -50), char, fill=0, font=font)
        
        # Add noise to the image
        image_array = np.array(image)
        noise = np.random.normal(0, 10, size=(IMAGE_HEIGHT, IMAGE_WIDTH))
        image_array = np.clip(image_array + noise, 0, 255).astype(np.uint8)
        image = Image.fromarray(image_array)
        
        # Save the image
        filename = f'{char} ({i}).png'
        filepath = os.path.join(OUTPUT_DIR+char, filename)
        image.save(filepath)

# Define the number of images to be generated for each character
NUM_IMAGES_PER_CHARACTER = 2

# Define the output directory for the dataset
OUTPUT_DIR = 'dataset_Test/'
if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR)
# Create the output directory if it doesn't exist
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# Load the Thai font
font = ImageFont.truetype(THAI_FONT_FILE, IMAGE_WIDTH)

# Generate the images
for char in CHARACTERS:
    if not os.path.exists(OUTPUT_DIR+char):
        os.makedirs(OUTPUT_DIR+char)
    for i in range(NUM_IMAGES_PER_CHARACTER):
        # Create a new image
        image = Image.new('L', (IMAGE_WIDTH, IMAGE_HEIGHT), color=255)
        
        # Draw the character on the image
        draw = ImageDraw.Draw(image)
        draw.text((20, -50), char, fill=0, font=font)
        
        # Add noise to the image
        image_array = np.array(image)
        noise = np.random.normal(0, 10, size=(IMAGE_HEIGHT, IMAGE_WIDTH))
        image_array = np.clip(image_array + noise, 0, 255).astype(np.uint8)
        image = Image.fromarray(image_array)
        
        # Save the image
        filename = f'{char} ({i}).png'
        filepath = os.path.join(OUTPUT_DIR+char, filename)
        image.save(filepath)

# %%
import keras
from keras.datasets import cifar10
from keras.utils import image_dataset_from_directory, to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

import numpy as np
import os, random, tensorflow as tf

def set_seed(seed_value=1234):
    random.seed(seed_value)
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)
    os.environ['PYTHONHASHSEED'] = str(seed_value)

set_seed(1234)

datagen = ImageDataGenerator(
    rescale=1./255,
    brightness_range=(0.2,0.8),
    shear_range=0.2,
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=True,  # apply ZCA whitening
    rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,)

test_datagen = ImageDataGenerator(rescale=1./255)

train = datagen.flow_from_directory('dataset', subset="training", color_mode = 'grayscale',batch_size=20, seed=1234,target_size=(72, 72))
val = test_datagen.flow_from_directory('dataset_Test', color_mode = 'grayscale',batch_size=20, seed=1234,target_size=(72, 72))





num_classes = len(train.class_indices)

labels = dict((v,k) for k,v in train.class_indices.items())
# Out:
# Found 448 images belonging to 56 classes.
# Found 112 images belonging to 56 classes.

# %%
model_1 = Sequential()


model_1.add(Conv2D(32, (5, 5), strides = (2,2), padding='same',
                 input_shape=(72,72,1)))
model_1.add(Activation('relu'))
model_1.add(Conv2D(32, (5, 5), strides = (2,2)))
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2)))
model_1.add(Dropout(0.25))
model_1.add(Flatten())
model_1.add(Dense(512))
model_1.add(Activation('relu'))
model_1.add(Dropout(0.5))
model_1.add(Dense(num_classes))
model_1.add(Activation('softmax'))

model_1.summary()

batch_size = 64

# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(lr=0.0005, decay=1e-6)

# Let's train the model using RMSprop
model_1.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

print(train)
STEP_SIZE_TRAIN=train.n//train.batch_size
STEP_SIZE_VALID=val.n//val.batch_size
model_1.fit_generator(generator=train,
            steps_per_epoch=STEP_SIZE_TRAIN,
            epochs=150,
            validation_steps=STEP_SIZE_VALID,
            validation_data=val)

model_1.save('OCR.h5')
# Out:
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_56 (Conv2D)          (None, 36, 36, 32)        832
#
#  activation_112 (Activation)  (None, 36, 36, 32)       0
#
#  conv2d_57 (Conv2D)          (None, 16, 16, 32)        25632
#
#  activation_113 (Activation)  (None, 16, 16, 32)       0
#
#  max_pooling2d_28 (MaxPoolin  (None, 8, 8, 32)         0
#  g2D)
#
#  dropout_56 (Dropout)        (None, 8, 8, 32)          0
#
#  flatten_28 (Flatten)        (None, 2048)              0
#
#  dense_56 (Dense)            (None, 512)               1049088
#
#  activation_114 (Activation)  (None, 512)              0
#
#  dropout_57 (Dropout)        (None, 512)               0
#
#  dense_57 (Dense)            (None, 56)                28728
#
#  activation_115 (Activation)  (None, 56)               0
#
# =================================================================
# Total params: 1,104,280
# Trainable params: 1,104,280
# Non-trainable params: 0
# _________________________________________________________________
# <keras.preprocessing.image.DirectoryIterator object at 0x7f0b4f15de50>
# Epoch 1/150
# <ipython-input-70-1b56bbca043e>:37: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_1.fit_generator(generator=train,
# 22/22 [==============================] - 3s 103ms/step - loss: 4.0465 - accuracy: 0.0117 - val_loss: 4.0168 - val_accuracy: 0.0100
# Epoch 2/150
# 22/22 [==============================] - 2s 90ms/step - loss: 4.0212 - accuracy: 0.0187 - val_loss: 3.9875 - val_accuracy: 0.0600
# Epoch 3/150
# 22/22 [==============================] - 2s 89ms/step - loss: 4.0124 - accuracy: 0.0210 - val_loss: 3.9257 - val_accuracy: 0.1100
# Epoch 4/150
# 22/22 [==============================] - 3s 153ms/step - loss: 3.9723 - accuracy: 0.0514 - val_loss: 3.7182 - val_accuracy: 0.1200
# Epoch 5/150
# 22/22 [==============================] - 2s 88ms/step - loss: 3.9162 - accuracy: 0.0631 - val_loss: 3.3760 - val_accuracy: 0.2300
# Epoch 6/150
# 22/22 [==============================] - 2s 89ms/step - loss: 3.7624 - accuracy: 0.1028 - val_loss: 2.9076 - val_accuracy: 0.4000
# Epoch 7/150
# 22/22 [==============================] - 2s 90ms/step - loss: 3.5033 - accuracy: 0.1565 - val_loss: 2.3400 - val_accuracy: 0.4500
# Epoch 8/150
# 22/22 [==============================] - 3s 144ms/step - loss: 3.3130 - accuracy: 0.1636 - val_loss: 1.9352 - val_accuracy: 0.4500
# Epoch 9/150
# 22/22 [==============================] - 2s 86ms/step - loss: 3.1635 - accuracy: 0.1682 - val_loss: 1.8607 - val_accuracy: 0.3900
# Epoch 10/150
# 22/22 [==============================] - 2s 88ms/step - loss: 2.9083 - accuracy: 0.2313 - val_loss: 1.4702 - val_accuracy: 0.4700
# Epoch 11/150
# 22/22 [==============================] - 2s 90ms/step - loss: 2.7559 - accuracy: 0.2383 - val_loss: 1.2920 - val_accuracy: 0.6100
# Epoch 12/150
# 22/22 [==============================] - 2s 90ms/step - loss: 2.6341 - accuracy: 0.2570 - val_loss: 1.0872 - val_accuracy: 0.6400
# Epoch 13/150
# 22/22 [==============================] - 3s 143ms/step - loss: 2.4246 - accuracy: 0.3131 - val_loss: 0.9999 - val_accuracy: 0.6600
# Epoch 14/150
# 22/22 [==============================] - 2s 88ms/step - loss: 2.3360 - accuracy: 0.2967 - val_loss: 0.9826 - val_accuracy: 0.6000
# Epoch 15/150
# 22/22 [==============================] - 2s 89ms/step - loss: 2.1461 - accuracy: 0.3598 - val_loss: 0.7818 - val_accuracy: 0.6900
# Epoch 16/150
# 22/22 [==============================] - 2s 90ms/step - loss: 2.0857 - accuracy: 0.4322 - val_loss: 0.7936 - val_accuracy: 0.7300
# Epoch 17/150
# 22/22 [==============================] - 2s 104ms/step - loss: 1.9211 - accuracy: 0.4416 - val_loss: 0.6424 - val_accuracy: 0.7500
# Epoch 18/150
# 22/22 [==============================] - 3s 132ms/step - loss: 1.9360 - accuracy: 0.4229 - val_loss: 0.6262 - val_accuracy: 0.8100
# Epoch 19/150
# 22/22 [==============================] - 2s 88ms/step - loss: 1.8409 - accuracy: 0.4276 - val_loss: 0.5407 - val_accuracy: 0.8400
# Epoch 20/150
# 22/22 [==============================] - 2s 86ms/step - loss: 1.7226 - accuracy: 0.4766 - val_loss: 0.5804 - val_accuracy: 0.7800
# Epoch 21/150
# 22/22 [==============================] - 2s 89ms/step - loss: 1.7196 - accuracy: 0.4626 - val_loss: 0.5669 - val_accuracy: 0.8200
# Epoch 22/150
# 22/22 [==============================] - 3s 155ms/step - loss: 1.7147 - accuracy: 0.4720 - val_loss: 0.5062 - val_accuracy: 0.8000
# Epoch 23/150
# 22/22 [==============================] - 2s 91ms/step - loss: 1.5213 - accuracy: 0.5093 - val_loss: 0.4958 - val_accuracy: 0.8200
# Epoch 24/150
# 22/22 [==============================] - 2s 89ms/step - loss: 1.5476 - accuracy: 0.5093 - val_loss: 0.4486 - val_accuracy: 0.7900
# Epoch 25/150
# 22/22 [==============================] - 2s 90ms/step - loss: 1.4423 - accuracy: 0.5561 - val_loss: 0.3906 - val_accuracy: 0.8700
# Epoch 26/150
# 22/22 [==============================] - 3s 130ms/step - loss: 1.4384 - accuracy: 0.5514 - val_loss: 0.3900 - val_accuracy: 0.8700
# Epoch 27/150
# 22/22 [==============================] - 2s 88ms/step - loss: 1.4595 - accuracy: 0.5187 - val_loss: 0.4501 - val_accuracy: 0.7700
# Epoch 28/150
# 22/22 [==============================] - 2s 88ms/step - loss: 1.2627 - accuracy: 0.5841 - val_loss: 0.3084 - val_accuracy: 0.8700
# Epoch 29/150
# 22/22 [==============================] - 2s 90ms/step - loss: 1.2977 - accuracy: 0.6000 - val_loss: 0.3235 - val_accuracy: 0.8600
# Epoch 30/150
# 22/22 [==============================] - 2s 92ms/step - loss: 1.1758 - accuracy: 0.5911 - val_loss: 0.3252 - val_accuracy: 0.8600
# Epoch 31/150
# 22/22 [==============================] - 3s 124ms/step - loss: 1.3011 - accuracy: 0.5561 - val_loss: 0.3238 - val_accuracy: 0.8800
# Epoch 32/150
# 22/22 [==============================] - 2s 85ms/step - loss: 1.1587 - accuracy: 0.6005 - val_loss: 0.3580 - val_accuracy: 0.8600
# Epoch 33/150
# 22/22 [==============================] - 2s 89ms/step - loss: 1.1500 - accuracy: 0.6192 - val_loss: 0.3114 - val_accuracy: 0.9000
# Epoch 34/150
# 22/22 [==============================] - 2s 89ms/step - loss: 1.2016 - accuracy: 0.6075 - val_loss: 0.2970 - val_accuracy: 0.9000
# Epoch 35/150
# 22/22 [==============================] - 2s 89ms/step - loss: 1.0775 - accuracy: 0.6565 - val_loss: 0.3109 - val_accuracy: 0.8700
# Epoch 36/150
# 22/22 [==============================] - 3s 148ms/step - loss: 1.0077 - accuracy: 0.6565 - val_loss: 0.3627 - val_accuracy: 0.8500
# Epoch 37/150
# 22/22 [==============================] - 2s 90ms/step - loss: 1.0613 - accuracy: 0.6355 - val_loss: 0.2048 - val_accuracy: 0.9100
# Epoch 38/150
# 22/22 [==============================] - 2s 87ms/step - loss: 0.9852 - accuracy: 0.6542 - val_loss: 0.2460 - val_accuracy: 0.9200
# Epoch 39/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.9789 - accuracy: 0.6589 - val_loss: 0.2651 - val_accuracy: 0.8500
# Epoch 40/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.9772 - accuracy: 0.6565 - val_loss: 0.2281 - val_accuracy: 0.9400
# Epoch 41/150
# 22/22 [==============================] - 3s 145ms/step - loss: 0.8998 - accuracy: 0.6893 - val_loss: 0.2561 - val_accuracy: 0.8800
# Epoch 42/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.8953 - accuracy: 0.6846 - val_loss: 0.2417 - val_accuracy: 0.8900
# Epoch 43/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.9568 - accuracy: 0.6612 - val_loss: 0.2125 - val_accuracy: 0.8900
# Epoch 44/150
# 22/22 [==============================] - 2s 87ms/step - loss: 0.8980 - accuracy: 0.7103 - val_loss: 0.1940 - val_accuracy: 0.8800
# Epoch 45/150
# 22/22 [==============================] - 3s 139ms/step - loss: 0.9336 - accuracy: 0.7033 - val_loss: 0.1378 - val_accuracy: 0.9700
# Epoch 46/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.7963 - accuracy: 0.7266 - val_loss: 0.1825 - val_accuracy: 0.9300
# Epoch 47/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.7658 - accuracy: 0.7477 - val_loss: 0.1616 - val_accuracy: 0.9400
# Epoch 48/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.8109 - accuracy: 0.7173 - val_loss: 0.1556 - val_accuracy: 0.9300
# Epoch 49/150
# 22/22 [==============================] - 2s 103ms/step - loss: 0.6994 - accuracy: 0.7640 - val_loss: 0.1726 - val_accuracy: 0.9500
# Epoch 50/150
# 22/22 [==============================] - 4s 189ms/step - loss: 0.7448 - accuracy: 0.7523 - val_loss: 0.1529 - val_accuracy: 0.9300
# Epoch 51/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.7387 - accuracy: 0.7500 - val_loss: 0.1806 - val_accuracy: 0.9200
# Epoch 52/150
# 22/22 [==============================] - 2s 87ms/step - loss: 0.7073 - accuracy: 0.7477 - val_loss: 0.1182 - val_accuracy: 0.9200
# Epoch 53/150
# 22/22 [==============================] - 2s 87ms/step - loss: 0.7567 - accuracy: 0.7336 - val_loss: 0.1091 - val_accuracy: 0.9700
# Epoch 54/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.6513 - accuracy: 0.7682 - val_loss: 0.1333 - val_accuracy: 0.9500
# Epoch 55/150
# 22/22 [==============================] - 3s 130ms/step - loss: 0.6088 - accuracy: 0.7804 - val_loss: 0.1148 - val_accuracy: 0.9800
# Epoch 56/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.6976 - accuracy: 0.7570 - val_loss: 0.0837 - val_accuracy: 0.9800
# Epoch 57/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.6598 - accuracy: 0.7734 - val_loss: 0.0994 - val_accuracy: 0.9500
# Epoch 58/150
# 22/22 [==============================] - 2s 88ms/step - loss: 0.6698 - accuracy: 0.7617 - val_loss: 0.2199 - val_accuracy: 0.8900
# Epoch 59/150
# 22/22 [==============================] - 3s 135ms/step - loss: 0.6888 - accuracy: 0.7570 - val_loss: 0.1313 - val_accuracy: 0.9400
# Epoch 60/150
# 22/22 [==============================] - 2s 88ms/step - loss: 0.6786 - accuracy: 0.7664 - val_loss: 0.0934 - val_accuracy: 0.9400
# Epoch 61/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.5548 - accuracy: 0.8084 - val_loss: 0.1167 - val_accuracy: 0.9600
# Epoch 62/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.6220 - accuracy: 0.8084 - val_loss: 0.1773 - val_accuracy: 0.9100
# Epoch 63/150
# 22/22 [==============================] - 3s 123ms/step - loss: 0.5262 - accuracy: 0.8136 - val_loss: 0.0671 - val_accuracy: 1.0000
# Epoch 64/150
# 22/22 [==============================] - 3s 110ms/step - loss: 0.5532 - accuracy: 0.8131 - val_loss: 0.0644 - val_accuracy: 0.9900
# Epoch 65/150
# 22/22 [==============================] - 2s 87ms/step - loss: 0.5856 - accuracy: 0.7874 - val_loss: 0.0611 - val_accuracy: 0.9800
# Epoch 66/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.5578 - accuracy: 0.8201 - val_loss: 0.0764 - val_accuracy: 0.9800
# Epoch 67/150
# 22/22 [==============================] - 2s 88ms/step - loss: 0.4868 - accuracy: 0.7967 - val_loss: 0.0821 - val_accuracy: 0.9800
# Epoch 68/150
# 22/22 [==============================] - 2s 101ms/step - loss: 0.5099 - accuracy: 0.8294 - val_loss: 0.0894 - val_accuracy: 0.9600
# Epoch 69/150
# 22/22 [==============================] - 3s 125ms/step - loss: 0.5463 - accuracy: 0.7757 - val_loss: 0.0869 - val_accuracy: 0.9300
# Epoch 70/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.4807 - accuracy: 0.8294 - val_loss: 0.0555 - val_accuracy: 0.9700
# Epoch 71/150
# 22/22 [==============================] - 2s 88ms/step - loss: 0.4824 - accuracy: 0.8178 - val_loss: 0.0650 - val_accuracy: 1.0000
# Epoch 72/150
# 22/22 [==============================] - 2s 87ms/step - loss: 0.5038 - accuracy: 0.8224 - val_loss: 0.0520 - val_accuracy: 1.0000
# Epoch 73/150
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5000 - accuracy: 0.8201 - val_loss: 0.0677 - val_accuracy: 0.9600
# Epoch 74/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.4442 - accuracy: 0.8435 - val_loss: 0.1044 - val_accuracy: 0.9600
# Epoch 75/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.5289 - accuracy: 0.8037 - val_loss: 0.0657 - val_accuracy: 0.9800
# Epoch 76/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.4365 - accuracy: 0.8598 - val_loss: 0.0873 - val_accuracy: 0.9400
# Epoch 77/150
# 22/22 [==============================] - 2s 99ms/step - loss: 0.4415 - accuracy: 0.8341 - val_loss: 0.1034 - val_accuracy: 0.9600
# Epoch 78/150
# 22/22 [==============================] - 3s 134ms/step - loss: 0.4316 - accuracy: 0.8435 - val_loss: 0.0546 - val_accuracy: 0.9900
# Epoch 79/150
# 22/22 [==============================] - 2s 93ms/step - loss: 0.4114 - accuracy: 0.8458 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 80/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.4496 - accuracy: 0.8435 - val_loss: 0.0794 - val_accuracy: 0.9700
# Epoch 81/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.4076 - accuracy: 0.8598 - val_loss: 0.0633 - val_accuracy: 0.9600
# Epoch 82/150
# 22/22 [==============================] - 3s 143ms/step - loss: 0.4253 - accuracy: 0.8458 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 83/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.3969 - accuracy: 0.8715 - val_loss: 0.0437 - val_accuracy: 1.0000
# Epoch 84/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.4577 - accuracy: 0.8318 - val_loss: 0.0461 - val_accuracy: 0.9800
# Epoch 85/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.3911 - accuracy: 0.8575 - val_loss: 0.0646 - val_accuracy: 0.9600
# Epoch 86/150
# 22/22 [==============================] - 3s 122ms/step - loss: 0.3397 - accuracy: 0.8668 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 87/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.3838 - accuracy: 0.8645 - val_loss: 0.0871 - val_accuracy: 0.9400
# Epoch 88/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.3523 - accuracy: 0.8785 - val_loss: 0.0449 - val_accuracy: 0.9900
# Epoch 89/150
# 22/22 [==============================] - 2s 87ms/step - loss: 0.3744 - accuracy: 0.8621 - val_loss: 0.0649 - val_accuracy: 0.9800
# Epoch 90/150
# 22/22 [==============================] - 3s 115ms/step - loss: 0.4222 - accuracy: 0.8505 - val_loss: 0.0669 - val_accuracy: 0.9600
# Epoch 91/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.4031 - accuracy: 0.8364 - val_loss: 0.0627 - val_accuracy: 0.9800
# Epoch 92/150
# 22/22 [==============================] - 2s 88ms/step - loss: 0.3909 - accuracy: 0.8575 - val_loss: 0.0553 - val_accuracy: 0.9800
# Epoch 93/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.3900 - accuracy: 0.8614 - val_loss: 0.0655 - val_accuracy: 0.9800
# Epoch 94/150
# 22/22 [==============================] - 2s 108ms/step - loss: 0.3616 - accuracy: 0.8575 - val_loss: 0.0753 - val_accuracy: 0.9900
# Epoch 95/150
# 22/22 [==============================] - 3s 122ms/step - loss: 0.3220 - accuracy: 0.8762 - val_loss: 0.0831 - val_accuracy: 0.9500
# Epoch 96/150
# 22/22 [==============================] - 2s 94ms/step - loss: 0.3448 - accuracy: 0.8645 - val_loss: 0.1091 - val_accuracy: 0.9500
# Epoch 97/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.2845 - accuracy: 0.9019 - val_loss: 0.0636 - val_accuracy: 0.9700
# Epoch 98/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.3315 - accuracy: 0.8762 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 99/150
# 22/22 [==============================] - 3s 151ms/step - loss: 0.3549 - accuracy: 0.8692 - val_loss: 0.0795 - val_accuracy: 0.9600
# Epoch 100/150
# 22/22 [==============================] - 2s 96ms/step - loss: 0.2844 - accuracy: 0.8855 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 101/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.2957 - accuracy: 0.8879 - val_loss: 0.1074 - val_accuracy: 0.9500
# Epoch 102/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.3035 - accuracy: 0.8925 - val_loss: 0.0521 - val_accuracy: 0.9800
# Epoch 103/150
# 22/22 [==============================] - 3s 142ms/step - loss: 0.2891 - accuracy: 0.8832 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 104/150
# 22/22 [==============================] - 2s 93ms/step - loss: 0.2954 - accuracy: 0.9019 - val_loss: 0.0312 - val_accuracy: 0.9800
# Epoch 105/150
# 22/22 [==============================] - 2s 92ms/step - loss: 0.2601 - accuracy: 0.8925 - val_loss: 0.0505 - val_accuracy: 0.9800
# Epoch 106/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.3194 - accuracy: 0.8902 - val_loss: 0.0385 - val_accuracy: 1.0000
# Epoch 107/150
# 22/22 [==============================] - 2s 109ms/step - loss: 0.3251 - accuracy: 0.8879 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 108/150
# 22/22 [==============================] - 3s 131ms/step - loss: 0.2916 - accuracy: 0.8972 - val_loss: 0.0423 - val_accuracy: 0.9600
# Epoch 109/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.3083 - accuracy: 0.8879 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 110/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.2723 - accuracy: 0.9182 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 111/150
# 22/22 [==============================] - 2s 88ms/step - loss: 0.2970 - accuracy: 0.8925 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 112/150
# 22/22 [==============================] - 3s 146ms/step - loss: 0.2782 - accuracy: 0.9182 - val_loss: 0.0451 - val_accuracy: 0.9800
# Epoch 113/150
# 22/22 [==============================] - 2s 88ms/step - loss: 0.2694 - accuracy: 0.8949 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 114/150
# 22/22 [==============================] - 2s 88ms/step - loss: 0.2441 - accuracy: 0.9065 - val_loss: 0.0434 - val_accuracy: 0.9800
# Epoch 115/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.2721 - accuracy: 0.9136 - val_loss: 0.0219 - val_accuracy: 0.9900
# Epoch 116/150
# 22/22 [==============================] - 3s 122ms/step - loss: 0.2735 - accuracy: 0.9182 - val_loss: 0.0300 - val_accuracy: 0.9800
# Epoch 117/150
# 22/22 [==============================] - 2s 87ms/step - loss: 0.2510 - accuracy: 0.9112 - val_loss: 0.0379 - val_accuracy: 0.9800
# Epoch 118/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.2715 - accuracy: 0.9159 - val_loss: 0.0284 - val_accuracy: 1.0000
# Epoch 119/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.2228 - accuracy: 0.9159 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 120/150
# 22/22 [==============================] - 3s 131ms/step - loss: 0.2848 - accuracy: 0.9042 - val_loss: 0.0299 - val_accuracy: 0.9800
# Epoch 121/150
# 22/22 [==============================] - 2s 92ms/step - loss: 0.2744 - accuracy: 0.9136 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 122/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.2119 - accuracy: 0.9276 - val_loss: 0.0189 - val_accuracy: 0.9800
# Epoch 123/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.2172 - accuracy: 0.9322 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 124/150
# 22/22 [==============================] - 3s 117ms/step - loss: 0.2610 - accuracy: 0.9089 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 125/150
# 22/22 [==============================] - 3s 116ms/step - loss: 0.2942 - accuracy: 0.8879 - val_loss: 0.0537 - val_accuracy: 0.9800
# Epoch 126/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.1953 - accuracy: 0.9229 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 127/150
# 22/22 [==============================] - 3s 147ms/step - loss: 0.2564 - accuracy: 0.9023 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 128/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.2286 - accuracy: 0.9159 - val_loss: 0.0212 - val_accuracy: 0.9800
# Epoch 129/150
# 22/22 [==============================] - 2s 92ms/step - loss: 0.3063 - accuracy: 0.9089 - val_loss: 0.0336 - val_accuracy: 0.9800
# Epoch 130/150
# 22/22 [==============================] - 2s 92ms/step - loss: 0.1853 - accuracy: 0.9322 - val_loss: 0.0262 - val_accuracy: 0.9800
# Epoch 131/150
# 22/22 [==============================] - 3s 118ms/step - loss: 0.2242 - accuracy: 0.9182 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 132/150
# 22/22 [==============================] - 2s 92ms/step - loss: 0.2553 - accuracy: 0.8879 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 133/150
# 22/22 [==============================] - 2s 92ms/step - loss: 0.2569 - accuracy: 0.9019 - val_loss: 0.0282 - val_accuracy: 0.9700
# Epoch 134/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.2108 - accuracy: 0.9322 - val_loss: 0.0204 - val_accuracy: 0.9800
# Epoch 135/150
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2043 - accuracy: 0.9159 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 136/150
# 22/22 [==============================] - 3s 134ms/step - loss: 0.1781 - accuracy: 0.9369 - val_loss: 0.0211 - val_accuracy: 0.9800
# Epoch 137/150
# 22/22 [==============================] - 2s 90ms/step - loss: 0.2494 - accuracy: 0.9136 - val_loss: 0.0222 - val_accuracy: 0.9800
# Epoch 138/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.2019 - accuracy: 0.9299 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 139/150
# 22/22 [==============================] - 2s 89ms/step - loss: 0.2338 - accuracy: 0.9159 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 140/150
# 22/22 [==============================] - 3s 143ms/step - loss: 0.2135 - accuracy: 0.9112 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 141/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.1828 - accuracy: 0.9322 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 142/150
# 22/22 [==============================] - 2s 93ms/step - loss: 0.1703 - accuracy: 0.9439 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 143/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.1648 - accuracy: 0.9533 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 144/150
# 22/22 [==============================] - 2s 103ms/step - loss: 0.2159 - accuracy: 0.9276 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 145/150
# 22/22 [==============================] - 3s 126ms/step - loss: 0.2097 - accuracy: 0.9182 - val_loss: 0.0454 - val_accuracy: 0.9600
# Epoch 146/150
# 22/22 [==============================] - 2s 92ms/step - loss: 0.2300 - accuracy: 0.9252 - val_loss: 0.0402 - val_accuracy: 0.9800
# Epoch 147/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.1874 - accuracy: 0.9295 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 148/150
# 22/22 [==============================] - 2s 94ms/step - loss: 0.1723 - accuracy: 0.9416 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 149/150
# 22/22 [==============================] - 3s 157ms/step - loss: 0.2051 - accuracy: 0.9299 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 150/150
# 22/22 [==============================] - 2s 91ms/step - loss: 0.2008 - accuracy: 0.9299 - val_loss: 0.0256 - val_accuracy: 1.0000

# %%
import cv2
import imutils
from keras.models import load_model
from tensorflow.keras.utils import img_to_array
import functools
import numpy as np
from google.colab.patches import cv2_imshow

original_image = cv2.imread('image9.jpg')
#cv2.imshow('image',original_image)

original_image = imutils.resize(original_image, width=500 )
gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY) 
gray_image = cv2.bilateralFilter(gray_image, 11, 17, 17)

#cv2.imshow('image',original_image)
#cv2.imshow('image',gray_image)

edged_image = cv2.Canny(gray_image, 10, 200)
#cv2.imshow('image',edged_image)


contours, new = cv2.findContours(edged_image.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
img1 = original_image.copy()
cv2.drawContours(img1, contours, -1, (0, 0,255), 3)
#cv2.imshow('image',img1)
print(len(contours))


contours = sorted(contours, key = cv2.contourArea, reverse = True)[:100]
screenCnt = None
img2 = original_image.copy()

cv2.drawContours(img2, contours, -1, (0, 0,255), 3)
#cv2.imshow('image',img2)

count = 0
idx = 7

for c in contours :
    contour_perimeter = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.018 * contour_perimeter, True)

    if len(approx) == 4:
        screenCnt = approx
        x, y, w, h = cv2.boundingRect(c)
        new_img = original_image [ y: y + h, x: x + w]
        cv2.imwrite('cropped.png',new_img)
        idx += 1
        break
        
cv2.drawContours(original_image , [screenCnt], -1, (0, 0,255), 3)
#cv2.imshow('image',original_image )


cropped_License_Plate = 'cropped.png' 




image = cv2.imread(cropped_License_Plate)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


blurred = cv2.GaussianBlur(gray, (5, 5), 0)
thresh = cv2.adaptiveThreshold(blurred, 255,
    cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 45, 15)


_, labels = cv2.connectedComponents(thresh)
mask = np.zeros(thresh.shape, dtype="uint8")


total_pixels = image.shape[0] * image.shape[1]
lower = total_pixels // 70 
upper = total_pixels // 20 


for (i, label) in enumerate(np.unique(labels)):

    if label == 0:
        continue
 

    labelMask = np.zeros(thresh.shape, dtype="uint8")
    labelMask[labels == label] = 255
    numPixels = cv2.countNonZero(labelMask)
 

    if numPixels > lower and numPixels < upper:
        mask = cv2.add(mask, labelMask)
        

cnts, _ = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
boundingBoxes = [cv2.boundingRect(c) for c in cnts]


def compare(rect1, rect2):
    if abs(rect1[1] - rect2[1]) > 10:
        return rect1[1] - rect2[1]
    else:
        return rect1[0] - rect2[0]
boundingBoxes = sorted(boundingBoxes, key=functools.cmp_to_key(compare) )


TARGET_WIDTH = 72
TARGET_HEIGHT = 72
chars = ''.join([
    '0123456789',
    'กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรฤลฦวศษสหฬอฮ' 
])
model = load_model('OCR.h5')

vehicle_plate = ""

for rect in boundingBoxes:

    x,y,w,h = rect

    crop = mask[y:y+h, x:x+w]
    crop = cv2.bitwise_not(crop)

    rows = crop.shape[0]
    columns = crop.shape[1]
    paddingY = (TARGET_HEIGHT - rows) // 2 if rows < TARGET_HEIGHT else int(0.17 * rows)
    paddingX = (TARGET_WIDTH - columns) // 2 if columns < TARGET_WIDTH else int(0.45 * columns)
    

    crop = cv2.copyMakeBorder(crop, paddingY, paddingY, paddingX, paddingX, cv2.BORDER_CONSTANT, None, 255)

    crop = cv2.resize(crop, (TARGET_WIDTH, TARGET_HEIGHT))
    cv2_imshow(crop)

    crop = crop.astype("float") / 255.0
    crop = img_to_array(crop)
    crop = np.expand_dims(crop, axis=0)

    prob = model.predict(crop)[0]
    idx = np.argsort(prob)[-1]
    vehicle_plate += chars[idx]

    cv2.rectangle(image, (x,y), (x+w,y+h), (0, 255, 0), 2)
    
# Show final image
cv2_imshow(image)
print("Vehicle plate: " + vehicle_plate)
# Out:
# 142
# <PIL.Image.Image image mode=L size=72x72 at 0x7F0B4EA56100>
# 1/1 [==============================] - 0s 329ms/step
# <PIL.Image.Image image mode=L size=72x72 at 0x7F0B4EA2E3D0>
# 1/1 [==============================] - 0s 42ms/step
# <PIL.Image.Image image mode=L size=72x72 at 0x7F0B4EA4D340>
# 1/1 [==============================] - 0s 166ms/step
# <PIL.Image.Image image mode=L size=72x72 at 0x7F0B4EA2E070>
# 1/1 [==============================] - 0s 131ms/step
# <PIL.Image.Image image mode=L size=72x72 at 0x7F0B4EA9FBB0>
# 1/1 [==============================] - 0s 207ms/step
# <PIL.Image.Image image mode=L size=72x72 at 0x7F0B4EA10AF0>
# 1/1 [==============================] - 0s 242ms/step
# <PIL.Image.Image image mode=L size=72x72 at 0x7F0B4E9F5A90>
# 1/1 [==============================] - 0s 159ms/step
# <PIL.Image.Image image mode=RGB size=253x106 at 0x7F0B4EA4DDC0>
# Vehicle plate: ษ5ภ5592
